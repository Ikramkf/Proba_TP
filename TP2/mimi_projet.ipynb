# %%
import numpy as np #random
def RPS():
    p1=np.random.choice(['R ','P','S']) 
    
    p2=np.random.choice(['R ','P','S'])

    if (p1=='R' and p2=='S')and(p1=='S' and p2=='P')and(p1=='P' and p2=='R'):
        return 1
    elif p1==p2:
        return 0
    else: 
        return 2

# %%
N=10000
L=[RPS()for k in range(N)]
p1=(L.count(1)/N)*100
p2=(L.count(2)/N)*100
px=(L.count(0)/N)*100
print(f'%p1 gagne ={p1}, %p2 gagne ={p2},% match num ={px}')
# Out:
# R
# S
# P
# R
# S
# S
# P
# R
# R
# S
# R
# R
# P
# P
# P
# P
# R
# S
# S
# P
# S
# P
# S
# P
# P
# R
# R
# R
# R
# R
# P
# P
# R
# R
# S
# R
# R
# P
# S
# S
# P
# R
# S
# R
# P
# P
# P
# S
# P
# P
# P
# S
# P
# P
# R
# R
# S
# P
# P
# P
# S
# P
# S
# S
# S
# P
# S
# R
# R
# R
# P
# R
# P
# R
# P
# P
# S
# P
# S
# S
# R
# P
# S
# P
# S
# S
# R
# P
# S
# S
# P
# R
# P
# S
# R
# S
# S
# S
# P
# P
# S
# P
# P
# P
# R
# S
# S
# P
# P
# S
# P
# P
# S
# S
# R
# P
# S
# R
# S
# R
# P
# R
# P
# S
# R
# S
# P
# S
# P
# S
# P
# P
# S
# P
# R
# S
# R
# S
# S
# S
# S
# P
# R
# S
# P
# R
# R
# R
# R
# P
# S
# P
# P
# P
# S
# S
# P
# S
# S
# R
# R
# S
# P
# P
# S
# S
# S
# R
# P
# P
# S
# P
# S
# P
# P
# P
# P
# R
# S
# S
# P
# S
# R
# S
# P
# S
# S
# S
# R
# S
# S
# P
# S
# R
# R
# R
# R
# P
# P
# R
# R
# P
# S
# R
# S
# P
# R
# R
# S
# R
# R
# S
# R
# P
# P
# R
# S
# R
# P
# S
# P
# P
# R
# S
# R
# S
# P
# P
# S
# P
# R
# P
# S
# P
# R
# R
# S
# S
# R
# P
# S
# P
# R
# S
# P
# P
# P
# P
# S
# S
# ...

# %%
RPS()
# Out:
# S
# P
# 2
